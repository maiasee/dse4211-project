# %% [markdown]
# ## Imports

# %%
from pathlib import Path
import json
import random
import itertools
import math
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## Configuration

# %%
DATA_DIR = Path("outputs/data")
LSTM_DIR = Path("outputs/lstm_ready_data")
OUTPUT_DIR = Path("outputs/lstm_model_output")
OUTPUT_DIR.mkdir(exist_ok=True)

TRAIN_PATH = DATA_DIR / "train_df.csv"
VAL_PATH   = DATA_DIR / "val_df.csv"
TEST_PATH  = DATA_DIR / "test_df.csv"
RAW_PANEL_PATH = DATA_DIR / "binance_data_raw.csv"

HORIZON = 7
LOSS_NAME = "mse"           # "mse" or "huber"
REGIME_LAST_FEATURE = True   # preprocessing notebook saves regime_label as the last feature
SEED = 42
USE_GPU_IF_AVAILABLE = True

# Hyperparameter tuning controls
N_CV_SPLITS = 3
RANDOM_SEARCH = True
N_RANDOM_CONFIGS = 18        
MAX_SEQ_LEN = 30   


# Parameter grid for hyperparameter tuning
SEQ_LEN_CANDIDATES = [10, 15, 20, 25, 30]

PARAM_GRID = {
    "seq_len": SEQ_LEN_CANDIDATES,
    "learning_rate": [0.001, 0.0005, 0.0001, 0.00005],
    "hidden_size": [32, 64, 128],
    "num_layers": [1, 2],
    "dropout": [0.0, 0.1, 0.2, 0.3],
    "batch_size": [32, 64],
    "epochs": [20, 35, 50],
    "weight_decay": [0.0, 1e-5, 1e-4],
    "patience": [5],
}

# %% [markdown]
# ## Reproducibility and device setup

# %%
def seed_everything(seed: int = 42) -> None:
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

seed_everything(SEED)
device = "cuda" if (USE_GPU_IF_AVAILABLE and torch.cuda.is_available()) else "cpu"
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# ## Load Data

# %%
def sort_panel(df: pd.DataFrame) -> pd.DataFrame:
    return df.sort_values(["crypto", "date"]).reset_index(drop=True)

train_df = sort_panel(pd.read_csv(TRAIN_PATH, parse_dates=["date"]))
val_df   = sort_panel(pd.read_csv(VAL_PATH,   parse_dates=["date"]))
test_df  = sort_panel(pd.read_csv(TEST_PATH,  parse_dates=["date"]))

train_files = sorted(LSTM_DIR.glob("X_train_*.npy"))
assets = [p.stem.replace("X_train_", "") for p in train_files]

print("Train CSV shape:", train_df.shape)
print("Val CSV shape:  ", val_df.shape)
print("Test CSV shape: ", test_df.shape)
print("Detected assets:", assets)

if not assets:
    raise FileNotFoundError(
        f"No per-asset X_train_*.npy files found in {LSTM_DIR.resolve()}."
    )
# Out:
# Train CSV shape: (11448, 18)
# Val CSV shape:   (2928, 18)
# Test CSV shape:  (2864, 18)
# Detected assets: ['ADAUSDT', 'BCHUSDT', 'BNBUSDT', 'BTCUSDT', 'ETHUSDT', 'LINKUSDT', 'LTCUSDT', 'XRPUSDT']

# %% [markdown]
# ## Boundary and leakage sanity checks
#
# The `target_7d` on a row dated `t` is meant to represent the return from `t+1` to `t+7`.
#
# That means:
#
# - the **last 7 rows** of train cannot safely be used for train targets if they would spill into validation
# - the **last 7 rows** of validation cannot safely be used for validation targets if they would spill into test
#
# The preprocessing notebook handled this by trimming the last 7 rows of each asset in train and validation before sequence creation. The code below rebuilds the same logic so we can verify the boundaries.

# %%
def trim_split_for_horizon(df: pd.DataFrame, horizon: int) -> pd.DataFrame:
    trimmed = []
    for asset, sub in df.groupby("crypto", sort=True):
        sub = sub.sort_values("date").copy()
        if len(sub) <= horizon:
            raise ValueError(f"Asset {asset} has only {len(sub)} rows; cannot trim horizon={horizon}.")
        trimmed.append(sub.iloc[:-horizon].copy())
    return pd.concat(trimmed, ignore_index=True)

safe_train = trim_split_for_horizon(train_df, HORIZON)
safe_val   = trim_split_for_horizon(val_df, HORIZON)
safe_test  = test_df.copy()  # preprocessing notebook assumes test was already made safe upstream

summary_rows = []
for split_name, df_ in {
    "train_raw": train_df,
    "train_safe": safe_train,
    "val_raw": val_df,
    "val_safe": safe_val,
    "test_used": safe_test,
}.items():
    counts = df_.groupby("crypto").size()
    summary_rows.append({
        "split": split_name,
        "date_min": df_["date"].min(),
        "date_max": df_["date"].max(),
        "rows_per_asset_min": int(counts.min()),
        "rows_per_asset_max": int(counts.max()),
    })

boundary_summary = pd.DataFrame(summary_rows)
display(boundary_summary)

if RAW_PANEL_PATH.exists():
    raw_panel = sort_panel(pd.read_csv(RAW_PANEL_PATH, parse_dates=["date"]))
    raw_max = raw_panel.groupby("crypto")["date"].max().rename("raw_max_date")
    test_max = test_df.groupby("crypto")["date"].max().rename("test_max_date")
    check = pd.concat([raw_max, test_max], axis=1).reset_index()
    check["days_between_raw_and_test_max"] = (check["raw_max_date"] - check["test_max_date"]).dt.days
    print("Optional raw-vs-test end-date check:")
    display(check)
else:
    print("Optional raw panel check skipped because data/binance_data_raw.csv was not found.")
# Out:
#         split   date_min   date_max  rows_per_asset_min  rows_per_asset_max
# 0   train_raw 2020-01-31 2023-12-31                1431                1431
# 1  train_safe 2020-01-31 2023-12-24                1424                1424
# 2     val_raw 2024-01-01 2024-12-31                 366                 366
# 3    val_safe 2024-01-01 2024-12-24                 359                 359
# 4   test_used 2025-01-01 2025-12-24                 358                 358
# Optional raw-vs-test end-date check:
#      crypto raw_max_date test_max_date  days_between_raw_and_test_max
# 0   ADAUSDT   2025-12-24    2025-12-24                              0
# 1   BCHUSDT   2025-12-24    2025-12-24                              0
# 2   BNBUSDT   2025-12-24    2025-12-24                              0
# 3   BTCUSDT   2025-12-24    2025-12-24                              0
# 4   ETHUSDT   2025-12-24    2025-12-24                              0
# 5  LINKUSDT   2025-12-24    2025-12-24                              0
# 6   LTCUSDT   2025-12-24    2025-12-24                              0
# 7   XRPUSDT   2025-12-24    2025-12-24                              0

# %% [markdown]
# ## Rebuild metadata for each asset
#
# The preprocessing notebook saved the `.npy` tensors, but for evaluation we still want to know:
#
# - which asset a forecast belongs to
# - which forecast-origin date the sample corresponds to
#
# Because the per-asset `.npy` arrays were built with the original `LOOKBACK = 30`, we can rebuild the metadata from the CSV splits and then assert that the number of rebuilt dates matches the number of saved targets.

# %%
def load_asset_arrays(asset: str, data_dir: Path = LSTM_DIR):
    X_train = np.load(data_dir / f"X_train_{asset}.npy")
    y_train = np.load(data_dir / f"y_train_{asset}.npy")
    X_val   = np.load(data_dir / f"X_val_{asset}.npy")
    y_val   = np.load(data_dir / f"y_val_{asset}.npy")
    X_test  = np.load(data_dir / f"X_test_{asset}.npy")
    y_test  = np.load(data_dir / f"y_test_{asset}.npy")
    return X_train, y_train, X_val, y_val, X_test, y_test


def rebuild_meta_dates_for_asset(asset: str, base_lookback: int):
    train_asset = train_df[train_df["crypto"] == asset].sort_values("date").copy()
    val_asset   = val_df[val_df["crypto"] == asset].sort_values("date").copy()
    test_asset  = test_df[test_df["crypto"] == asset].sort_values("date").copy()

    train_safe_asset = train_asset.iloc[:-HORIZON].copy()
    val_safe_asset   = val_asset.iloc[:-HORIZON].copy()
    test_safe_asset  = test_asset.copy()

    def build_meta(current_df: pd.DataFrame, history_df: pd.DataFrame | None):
        if history_df is not None:
            combined = pd.concat([history_df, current_df], ignore_index=True)
            combined = (
                combined.drop_duplicates(subset=["date"], keep="last")
                        .sort_values("date")
                        .reset_index(drop=True)
            )
        else:
            combined = current_df.sort_values("date").reset_index(drop=True)

        current_dates = set(current_df["date"])
        dates = combined["date"].to_numpy()
        rows = []

        for end_idx in range(base_lookback - 1, len(combined)):
            if pd.Timestamp(dates[end_idx]) not in current_dates:
                continue
            rows.append({"crypto": asset, "date": pd.Timestamp(dates[end_idx])})

        return pd.DataFrame(rows)

    meta_train = build_meta(train_safe_asset, history_df=None)
    meta_val   = build_meta(val_safe_asset,   history_df=train_safe_asset)
    meta_test  = build_meta(test_safe_asset,  history_df=pd.concat([train_safe_asset, val_safe_asset], ignore_index=True))
    return meta_train, meta_val, meta_test

# Quick shape inspection using the first asset
example_asset = assets[0]
X_train_ex, y_train_ex, X_val_ex, y_val_ex, X_test_ex, y_test_ex = load_asset_arrays(example_asset)
print(f"Example asset: {example_asset}")
print("X_train shape:", X_train_ex.shape)
print("y_train shape:", y_train_ex.shape)
print("Saved base lookback:", X_train_ex.shape[1])
# Out:
# Example asset: ADAUSDT
# X_train shape: (1395, 30, 12)
# y_train shape: (1395,)
# Saved base lookback: 30

# %% [markdown]
# ## Model definition
#
# The architecture is done in the following way:
#
# - LSTM stack with tunable `num_layers`
# - tunable `hidden_size`
# - dropout applied only when `num_layers > 1`
# - one dense output layer producing a single 7-day-return forecast
#
# This keeps the comparison between baseline and regime-aware models clean.

# %%
class CryptoLSTM(nn.Module):
    def __init__(self, input_size: int, hidden_size: int = 64, num_layers: int = 1, dropout: float = 0.0):
        super().__init__()
        effective_dropout = dropout if num_layers > 1 else 0.0
        self.lstm = nn.LSTM(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            dropout=effective_dropout,
        )
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x):
        out, _ = self.lstm(x)
        last_hidden = out[:, -1, :]
        pred = self.fc(last_hidden)
        return pred

# %% [markdown]
# ## Training, prediction, and CV helpers
#
# - **CV stage**: uses expanding-window train/validation splits inside the train sample and uses early stopping.
# - **Validation OOS stage**: after tuning, the model is fit on the full train split for the chosen number of epochs and predicts the validation split.
# - **Test OOS stage**: after tuning, the model is refit on **train + validation** for the chosen number of epochs and predicts the test split.
#
# This keeps the final test forecast properly out-of-sample

# %%
def get_loss_fn(loss_name: str):
    if loss_name.lower() == "mse":
        return nn.MSELoss()
    if loss_name.lower() == "huber":
        return nn.HuberLoss(delta=1.0)
    raise ValueError("LOSS_NAME must be 'mse' or 'huber'.")


def mse_score(y_true, y_pred):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    return float(np.mean((y_true - y_pred) ** 2))


def mae_score(y_true, y_pred):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    return float(np.mean(np.abs(y_true - y_pred)))


def directional_accuracy(y_true, y_pred):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    return float(np.mean(np.sign(y_true) == np.sign(y_pred)))


def make_loader(X, y, batch_size: int, shuffle: bool):
    X_tensor = torch.tensor(X, dtype=torch.float32)
    y_tensor = torch.tensor(y, dtype=torch.float32).view(-1, 1)
    ds = TensorDataset(X_tensor, y_tensor)
    return DataLoader(ds, batch_size=batch_size, shuffle=shuffle)


def fit_model(
    model,
    train_loader,
    lr: float,
    epochs: int,
    loss_name: str,
    weight_decay: float = 0.0,
    device: str = "cpu",
    val_loader=None,
    patience: int | None = None,
):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    criterion = get_loss_fn(loss_name)

    best_state = None
    best_val_loss = float("inf")
    epochs_no_improve = 0
    train_losses = []
    val_losses = []

    for epoch in range(epochs):
        model.train()
        running_train = 0.0

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            optimizer.zero_grad()
            pred = model(X_batch)
            loss = criterion(pred, y_batch)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            running_train += loss.item() * X_batch.size(0)

        train_loss = running_train / len(train_loader.dataset)
        train_losses.append(train_loss)

        if val_loader is not None:
            model.eval()
            running_val = 0.0
            with torch.no_grad():
                for X_batch, y_batch in val_loader:
                    X_batch = X_batch.to(device)
                    y_batch = y_batch.to(device)
                    pred = model(X_batch)
                    loss = criterion(pred, y_batch)
                    running_val += loss.item() * X_batch.size(0)

            val_loss = running_val / len(val_loader.dataset)
            val_losses.append(val_loss)

            if val_loss < best_val_loss:
                best_val_loss = val_loss
                best_state = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}
                epochs_no_improve = 0
            else:
                epochs_no_improve += 1

            if patience is not None and epochs_no_improve >= patience:
                break

    if val_loader is not None and best_state is not None:
        model.load_state_dict(best_state)

    history = {
        "train_losses": train_losses,
        "val_losses": val_losses,
        "best_val_loss": best_val_loss if val_loader is not None else None,
        "epochs_trained": len(train_losses),
    }
    return model, history


def predict_model(model, X, device: str = "cpu", batch_size: int = 512):
    model = model.to(device)
    model.eval()
    preds = []
    loader = DataLoader(torch.tensor(X, dtype=torch.float32), batch_size=batch_size, shuffle=False)
    with torch.no_grad():
        for X_batch in loader:
            X_batch = X_batch.to(device)
            batch_pred = model(X_batch).detach().cpu().numpy().reshape(-1)
            preds.append(batch_pred)
    return np.concatenate(preds)


def expanding_window_splits(n_obs: int, n_splits: int = 3, train_frac: float = 0.60, val_frac: float = 0.20):
    initial_train = max(30, int(n_obs * train_frac))
    val_size = max(15, int(n_obs * val_frac))

    if initial_train + val_size >= n_obs:
        raise ValueError("Training set is too short for the requested expanding-window CV setup.")

    remaining = n_obs - initial_train - val_size
    step = max(1, remaining // max(n_splits - 1, 1))

    splits = []
    for i in range(n_splits):
        train_end = initial_train + i * step
        val_start = train_end
        val_end = val_start + val_size
        if val_end <= n_obs:
            train_idx = np.arange(0, train_end)
            val_idx = np.arange(val_start, val_end)
            splits.append((train_idx, val_idx))

    if not splits:
        raise ValueError("No valid CV splits were created. Reduce n_splits or val_frac.")
    return splits

# %% [markdown]
# ## Hyperparameter search space

# %%
all_configs = [dict(zip(PARAM_GRID.keys(), values)) for values in itertools.product(*PARAM_GRID.values())]

if RANDOM_SEARCH:
    n_pick = min(N_RANDOM_CONFIGS, len(all_configs))
    search_configs = random.sample(all_configs, k=n_pick)
else:
    search_configs = all_configs

print(f"Total possible configs: {len(all_configs)}")
print(f"Configs to evaluate:    {len(search_configs)}")
print("Candidate sequence lengths:", SEQ_LEN_CANDIDATES)
# Out:
# Total possible configs: 8640
# Configs to evaluate:    18
# Candidate sequence lengths: [10, 15, 20, 25, 30]

# %% [markdown]
# ## Tuning logic
#
# Two small transformations happen before the model sees the data:
#
# 1. if `use_regime = False`, the notebook drops the last feature, which is the regime indicator
# 2. if `seq_len < saved_lookback`, the notebook slices the last `seq_len` timesteps from each saved window
#
# Then the config is scored with expanding-window CV on the train split.

# %%
def maybe_drop_regime(X: np.ndarray, use_regime: bool, regime_last_feature: bool = True) -> np.ndarray:
    if use_regime:
        return X
    if regime_last_feature:
        return X[:, :, :-1]
    raise ValueError("Notebook currently assumes regime indicator is the last feature when use_regime=False.")


def apply_seq_len(X: np.ndarray, seq_len: int) -> np.ndarray:
    if seq_len > X.shape[1]:
        raise ValueError(f"Requested seq_len={seq_len} but saved windows only have length {X.shape[1]}.")
    return X[:, -seq_len:, :]


def evaluate_config_cv(X_full, y, config, use_regime: bool, device: str):
    X_variant = maybe_drop_regime(X_full, use_regime=use_regime, regime_last_feature=REGIME_LAST_FEATURE)
    X_variant = apply_seq_len(X_variant, config["seq_len"])

    cv_losses = []
    splits = expanding_window_splits(len(X_variant), n_splits=N_CV_SPLITS)

    for train_idx, val_idx in splits:
        X_tr, y_tr = X_variant[train_idx], y[train_idx]
        X_va, y_va = X_variant[val_idx], y[val_idx]

        train_loader = make_loader(X_tr, y_tr, batch_size=config["batch_size"], shuffle=True)
        val_loader   = make_loader(X_va, y_va, batch_size=config["batch_size"], shuffle=False)

        model = CryptoLSTM(
            input_size=X_variant.shape[2],
            hidden_size=config["hidden_size"],
            num_layers=config["num_layers"],
            dropout=config["dropout"],
        )

        model, history = fit_model(
            model=model,
            train_loader=train_loader,
            val_loader=val_loader,
            lr=config["learning_rate"],
            epochs=config["epochs"],
            patience=config["patience"],
            loss_name=LOSS_NAME,
            weight_decay=config["weight_decay"],
            device=device,
        )

        cv_losses.append(history["best_val_loss"])

    return float(np.mean(cv_losses))


def tune_variant(X_train_full, y_train, use_regime: bool, search_configs: list[dict], device: str):
    max_saved_lookback = min(X_train_full.shape[1], MAX_SEQ_LEN)
    valid_configs = [cfg for cfg in search_configs if cfg["seq_len"] <= max_saved_lookback]

    results = []
    best_config = None
    best_score = float("inf")

    for i, cfg in enumerate(valid_configs, start=1):
        score = evaluate_config_cv(X_train_full, y_train, cfg, use_regime=use_regime, device=device)
        results.append({"config_id": i, "cv_mse": score, **cfg})

        if score < best_score:
            best_score = score
            best_config = cfg

        print(f"[{'REG' if use_regime else 'BASE'}] config {i}/{len(valid_configs)} | cv_mse={score:.8f} | {cfg}")

    results_df = pd.DataFrame(results).sort_values("cv_mse").reset_index(drop=True)
    return best_config, results_df

# %% [markdown]
# ## Final OOS forecast functions
#
# After hyperparameter tuning:
#
# - **validation forecasts** are produced by fitting on the full train split only
# - **test forecasts** are produced by refitting on train + validation, then forecasting test

# %%
def prepare_variant(X_full: np.ndarray, seq_len: int, use_regime: bool) -> np.ndarray:
    X_variant = maybe_drop_regime(X_full, use_regime=use_regime, regime_last_feature=REGIME_LAST_FEATURE)
    X_variant = apply_seq_len(X_variant, seq_len)
    return X_variant


def fit_for_validation_forecast(X_train_full, y_train, X_val_full, y_val, config, use_regime: bool, device: str):
    X_train_variant = prepare_variant(X_train_full, config["seq_len"], use_regime)
    X_val_variant   = prepare_variant(X_val_full,   config["seq_len"], use_regime)

    train_loader = make_loader(X_train_variant, y_train, batch_size=config["batch_size"], shuffle=True)
    model = CryptoLSTM(
        input_size=X_train_variant.shape[2],
        hidden_size=config["hidden_size"],
        num_layers=config["num_layers"],
        dropout=config["dropout"],
    )

    model, history = fit_model(
        model=model,
        train_loader=train_loader,
        val_loader=None,
        lr=config["learning_rate"],
        epochs=config["epochs"],
        patience=None,
        loss_name=LOSS_NAME,
        weight_decay=config["weight_decay"],
        device=device,
    )

    val_pred = predict_model(model, X_val_variant, device=device)
    metrics = {
        "val_mse": mse_score(y_val, val_pred),
        "val_mae": mae_score(y_val, val_pred),
        "val_da": directional_accuracy(y_val, val_pred),
    }
    return model, history, val_pred, metrics


def fit_for_test_forecast(X_train_full, y_train, X_val_full, y_val, X_test_full, y_test, config, use_regime: bool, device: str):
    X_train_variant = prepare_variant(X_train_full, config["seq_len"], use_regime)
    X_val_variant   = prepare_variant(X_val_full,   config["seq_len"], use_regime)
    X_test_variant  = prepare_variant(X_test_full,  config["seq_len"], use_regime)

    X_trainval = np.concatenate([X_train_variant, X_val_variant], axis=0)
    y_trainval = np.concatenate([y_train, y_val], axis=0)

    train_loader = make_loader(X_trainval, y_trainval, batch_size=config["batch_size"], shuffle=True)
    model = CryptoLSTM(
        input_size=X_trainval.shape[2],
        hidden_size=config["hidden_size"],
        num_layers=config["num_layers"],
        dropout=config["dropout"],
    )

    model, history = fit_model(
        model=model,
        train_loader=train_loader,
        val_loader=None,
        lr=config["learning_rate"],
        epochs=config["epochs"],
        patience=None,
        loss_name=LOSS_NAME,
        weight_decay=config["weight_decay"],
        device=device,
    )

    test_pred = predict_model(model, X_test_variant, device=device)
    metrics = {
        "test_mse": mse_score(y_test, test_pred),
        "test_mae": mae_score(y_test, test_pred),
        "test_da": directional_accuracy(y_test, test_pred),
    }
    return model, history, test_pred, metrics

# %% [markdown]
# ## Main training loop
#
# This loop does the following for each asset:
#
# 1. load the per-asset arrays
# 2. rebuild and verify metadata
# 3. tune the **baseline** model on train with expanding-window CV
# 4. tune the **regime-aware** model on train with expanding-window CV
# 5. produce OOS validation forecasts
# 6. refit on train+val and produce OOS test forecasts
# 7. save configs, metrics, histories, forecasts, and final model weights

# %%
all_summary_rows = []
all_forecast_rows = []

for asset in assets:
    print("=" * 90)
    print("Processing asset:", asset)

    X_train_full, y_train, X_val_full, y_val, X_test_full, y_test = load_asset_arrays(asset)
    base_lookback = X_train_full.shape[1]

    meta_train, meta_val, meta_test = rebuild_meta_dates_for_asset(asset, base_lookback=base_lookback)

    assert len(meta_train) == len(y_train), f"Meta mismatch in train for {asset}"
    assert len(meta_val) == len(y_val), f"Meta mismatch in val for {asset}"
    assert len(meta_test) == len(y_test), f"Meta mismatch in test for {asset}"

    # Asset-specific search space: respect the saved lookback and the hard cap of 30
    asset_search_configs = [cfg for cfg in search_configs if cfg["seq_len"] <= min(base_lookback, MAX_SEQ_LEN)]
    if not asset_search_configs:
        raise ValueError(f"No valid configs remain for {asset}. Saved lookback is {base_lookback}.")

    # Baseline model (without regime)
    print("Tuning baseline model...")
    best_base_config, base_tuning_df = tune_variant(
        X_train_full=X_train_full,
        y_train=y_train,
        use_regime=False,
        search_configs=asset_search_configs,
        device=device,
    )
    print("Best baseline config:", best_base_config)

    base_val_model, base_val_history, base_val_pred, base_val_metrics = fit_for_validation_forecast(
        X_train_full=X_train_full,
        y_train=y_train,
        X_val_full=X_val_full,
        y_val=y_val,
        config=best_base_config,
        use_regime=False,
        device=device,
    )

    base_test_model, base_test_history, base_test_pred, base_test_metrics = fit_for_test_forecast(
        X_train_full=X_train_full,
        y_train=y_train,
        X_val_full=X_val_full,
        y_val=y_val,
        X_test_full=X_test_full,
        y_test=y_test,
        config=best_base_config,
        use_regime=False,
        device=device,
    )

    # Regime-aware model 
    print("Tuning regime-aware model...")
    best_reg_config, reg_tuning_df = tune_variant(
        X_train_full=X_train_full,
        y_train=y_train,
        use_regime=True,
        search_configs=asset_search_configs,
        device=device,
    )
    print("Best regime config:", best_reg_config)

    reg_val_model, reg_val_history, reg_val_pred, reg_val_metrics = fit_for_validation_forecast(
        X_train_full=X_train_full,
        y_train=y_train,
        X_val_full=X_val_full,
        y_val=y_val,
        config=best_reg_config,
        use_regime=True,
        device=device,
    )

    reg_test_model, reg_test_history, reg_test_pred, reg_test_metrics = fit_for_test_forecast(
        X_train_full=X_train_full,
        y_train=y_train,
        X_val_full=X_val_full,
        y_val=y_val,
        X_test_full=X_test_full,
        y_test=y_test,
        config=best_reg_config,
        use_regime=True,
        device=device,
    )

    # Save outputs
    asset_dir = OUTPUT_DIR / asset
    asset_dir.mkdir(exist_ok=True)

    torch.save(base_test_model.state_dict(), asset_dir / "baseline_test_model.pt")
    torch.save(reg_test_model.state_dict(),  asset_dir / "regime_test_model.pt")

    with open(asset_dir / "baseline_best_config.json", "w") as f:
        json.dump(best_base_config, f, indent=2)
    with open(asset_dir / "regime_best_config.json", "w") as f:
        json.dump(best_reg_config, f, indent=2)

    pd.DataFrame({
        "epoch": np.arange(1, len(base_val_history["train_losses"]) + 1),
        "train_loss": base_val_history["train_losses"],
    }).to_csv(asset_dir / "baseline_val_fit_history.csv", index=False)

    pd.DataFrame({
        "epoch": np.arange(1, len(base_test_history["train_losses"]) + 1),
        "train_loss": base_test_history["train_losses"],
    }).to_csv(asset_dir / "baseline_test_fit_history.csv", index=False)

    pd.DataFrame({
        "epoch": np.arange(1, len(reg_val_history["train_losses"]) + 1),
        "train_loss": reg_val_history["train_losses"],
    }).to_csv(asset_dir / "regime_val_fit_history.csv", index=False)

    pd.DataFrame({
        "epoch": np.arange(1, len(reg_test_history["train_losses"]) + 1),
        "train_loss": reg_test_history["train_losses"],
    }).to_csv(asset_dir / "regime_test_fit_history.csv", index=False)

    base_tuning_df.to_csv(asset_dir / "baseline_tuning_results.csv", index=False)
    reg_tuning_df.to_csv(asset_dir / "regime_tuning_results.csv", index=False)

    # Forecast tables
    base_val_forecasts = meta_val.copy()
    base_val_forecasts["split"] = "val"
    base_val_forecasts["model_type"] = "baseline"
    base_val_forecasts["y_true"] = y_val
    base_val_forecasts["y_pred"] = base_val_pred

    base_test_forecasts = meta_test.copy()
    base_test_forecasts["split"] = "test"
    base_test_forecasts["model_type"] = "baseline"
    base_test_forecasts["y_true"] = y_test
    base_test_forecasts["y_pred"] = base_test_pred

    reg_val_forecasts = meta_val.copy()
    reg_val_forecasts["split"] = "val"
    reg_val_forecasts["model_type"] = "regime"
    reg_val_forecasts["y_true"] = y_val
    reg_val_forecasts["y_pred"] = reg_val_pred

    reg_test_forecasts = meta_test.copy()
    reg_test_forecasts["split"] = "test"
    reg_test_forecasts["model_type"] = "regime"
    reg_test_forecasts["y_true"] = y_test
    reg_test_forecasts["y_pred"] = reg_test_pred

    asset_forecasts = pd.concat(
        [base_val_forecasts, base_test_forecasts, reg_val_forecasts, reg_test_forecasts],
        ignore_index=True,
    )
    asset_forecasts.to_csv(asset_dir / "forecasts.csv", index=False)
    all_forecast_rows.append(asset_forecasts)

    # Summary rows
    all_summary_rows.extend([
        {
            "asset": asset,
            "model_type": "baseline",
            **base_val_metrics,
            **base_test_metrics,
            **{f"hp_{k}": v for k, v in best_base_config.items()},
        },
        {
            "asset": asset,
            "model_type": "regime",
            **reg_val_metrics,
            **reg_test_metrics,
            **{f"hp_{k}": v for k, v in best_reg_config.items()},
        },
    ])

summary_df = pd.DataFrame(all_summary_rows)
forecasts_df = pd.concat(all_forecast_rows, ignore_index=True)

summary_df.to_csv(OUTPUT_DIR / "summary_metrics.csv", index=False)
forecasts_df.to_csv(OUTPUT_DIR / "all_forecasts.csv", index=False)

print("Saved summary metrics to:", OUTPUT_DIR / "summary_metrics.csv")
print("Saved all forecasts to: ", OUTPUT_DIR / "all_forecasts.csv")
summary_df
# Out:
# ==========================================================================================
# Processing asset: ADAUSDT
# Tuning baseline model...
# [BASE] config 1/18 | cv_mse=0.00872512 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 2/18 | cv_mse=0.00893661 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 3/18 | cv_mse=0.00862326 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 4/18 | cv_mse=0.00882397 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 5/18 | cv_mse=0.00894001 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 6/18 | cv_mse=0.00876790 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 7/18 | cv_mse=0.00877702 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 8/18 | cv_mse=0.00874875 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 9/18 | cv_mse=0.00895145 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 10/18 | cv_mse=0.00904543 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 11/18 | cv_mse=0.00941846 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 12/18 | cv_mse=0.00884987 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 13/18 | cv_mse=0.00883790 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 14/18 | cv_mse=0.00909217 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 15/18 | cv_mse=0.00896232 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 16/18 | cv_mse=0.00926906 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 17/18 | cv_mse=0.00868987 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 18/18 | cv_mse=0.00891444 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best baseline config: {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Tuning regime-aware model...
# [REG] config 1/18 | cv_mse=0.00893712 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 2/18 | cv_mse=0.00928477 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 3/18 | cv_mse=0.00908198 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 4/18 | cv_mse=0.00924437 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 5/18 | cv_mse=0.00917575 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 6/18 | cv_mse=0.00900201 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 7/18 | cv_mse=0.00883314 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 8/18 | cv_mse=0.00940173 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 9/18 | cv_mse=0.00864393 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 10/18 | cv_mse=0.00885773 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 11/18 | cv_mse=0.00949201 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 12/18 | cv_mse=0.00886194 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 13/18 | cv_mse=0.00912289 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 14/18 | cv_mse=0.01022695 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 15/18 | cv_mse=0.00942910 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 16/18 | cv_mse=0.00900762 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 17/18 | cv_mse=0.00878204 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 18/18 | cv_mse=0.00873793 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best regime config: {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# ==========================================================================================
# Processing asset: BCHUSDT
# Tuning baseline model...
# [BASE] config 1/18 | cv_mse=0.01428211 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 2/18 | cv_mse=0.01441649 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 3/18 | cv_mse=0.01463011 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 4/18 | cv_mse=0.01441258 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 5/18 | cv_mse=0.01438035 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 6/18 | cv_mse=0.01413638 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 7/18 | cv_mse=0.01417846 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 8/18 | cv_mse=0.01441369 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 9/18 | cv_mse=0.01435756 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 10/18 | cv_mse=0.01462148 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 11/18 | cv_mse=0.01452124 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 12/18 | cv_mse=0.01434210 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 13/18 | cv_mse=0.01445679 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 14/18 | cv_mse=0.01440962 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 15/18 | cv_mse=0.01455826 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 16/18 | cv_mse=0.01452506 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 17/18 | cv_mse=0.01436687 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 18/18 | cv_mse=0.01439188 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best baseline config: {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# Tuning regime-aware model...
# [REG] config 1/18 | cv_mse=0.01427201 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 2/18 | cv_mse=0.01448809 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 3/18 | cv_mse=0.01408257 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 4/18 | cv_mse=0.01454444 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 5/18 | cv_mse=0.01465130 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 6/18 | cv_mse=0.01413446 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 7/18 | cv_mse=0.01438096 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 8/18 | cv_mse=0.01414749 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 9/18 | cv_mse=0.01472670 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 10/18 | cv_mse=0.01404751 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 11/18 | cv_mse=0.01449593 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 12/18 | cv_mse=0.01440960 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 13/18 | cv_mse=0.01419686 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 14/18 | cv_mse=0.01441664 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 15/18 | cv_mse=0.01476903 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 16/18 | cv_mse=0.01449838 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 17/18 | cv_mse=0.01440083 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 18/18 | cv_mse=0.01420405 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best regime config: {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# ==========================================================================================
# Processing asset: BNBUSDT
# Tuning baseline model...
# [BASE] config 1/18 | cv_mse=0.00483524 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 2/18 | cv_mse=0.00507002 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 3/18 | cv_mse=0.00511133 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 4/18 | cv_mse=0.00531394 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 5/18 | cv_mse=0.00526957 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 6/18 | cv_mse=0.00536247 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 7/18 | cv_mse=0.00472083 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 8/18 | cv_mse=0.00508281 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 9/18 | cv_mse=0.00568919 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 10/18 | cv_mse=0.00474744 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 11/18 | cv_mse=0.00533600 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 12/18 | cv_mse=0.00487372 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 13/18 | cv_mse=0.00488943 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 14/18 | cv_mse=0.00539365 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 15/18 | cv_mse=0.00721335 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 16/18 | cv_mse=0.00596106 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 17/18 | cv_mse=0.00490398 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 18/18 | cv_mse=0.00474619 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best baseline config: {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# Tuning regime-aware model...
# [REG] config 1/18 | cv_mse=0.00522373 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 2/18 | cv_mse=0.00500148 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 3/18 | cv_mse=0.00528011 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 4/18 | cv_mse=0.00469851 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 5/18 | cv_mse=0.00549687 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 6/18 | cv_mse=0.00495206 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 7/18 | cv_mse=0.00471482 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 8/18 | cv_mse=0.00520593 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 9/18 | cv_mse=0.00554439 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 10/18 | cv_mse=0.00485646 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 11/18 | cv_mse=0.00559288 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 12/18 | cv_mse=0.00484412 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 13/18 | cv_mse=0.00513310 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 14/18 | cv_mse=0.00531098 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 15/18 | cv_mse=0.00623814 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 16/18 | cv_mse=0.00561828 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 17/18 | cv_mse=0.00510458 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 18/18 | cv_mse=0.00484336 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best regime config: {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# ==========================================================================================
# Processing asset: BTCUSDT
# Tuning baseline model...
# [BASE] config 1/18 | cv_mse=0.00560953 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 2/18 | cv_mse=0.00545732 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 3/18 | cv_mse=0.00632952 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 4/18 | cv_mse=0.00506919 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 5/18 | cv_mse=0.00548248 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 6/18 | cv_mse=0.00513390 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 7/18 | cv_mse=0.00487152 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 8/18 | cv_mse=0.00544832 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 9/18 | cv_mse=0.00512065 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 10/18 | cv_mse=0.00495647 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 11/18 | cv_mse=0.00530048 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 12/18 | cv_mse=0.00492894 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 13/18 | cv_mse=0.00502524 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 14/18 | cv_mse=0.00534588 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 15/18 | cv_mse=0.01215077 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 16/18 | cv_mse=0.00553310 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 17/18 | cv_mse=0.00495652 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 18/18 | cv_mse=0.00497235 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best baseline config: {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# Tuning regime-aware model...
# [REG] config 1/18 | cv_mse=0.00522381 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 2/18 | cv_mse=0.00511585 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 3/18 | cv_mse=0.00540254 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 4/18 | cv_mse=0.00526918 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 5/18 | cv_mse=0.00568273 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 6/18 | cv_mse=0.00491613 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 7/18 | cv_mse=0.00493148 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 8/18 | cv_mse=0.00492983 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 9/18 | cv_mse=0.00572772 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 10/18 | cv_mse=0.00528484 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 11/18 | cv_mse=0.00580021 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 12/18 | cv_mse=0.00493448 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 13/18 | cv_mse=0.00513062 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 14/18 | cv_mse=0.00518285 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 15/18 | cv_mse=0.00643382 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 16/18 | cv_mse=0.00529676 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 17/18 | cv_mse=0.00527560 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 18/18 | cv_mse=0.00495810 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best regime config: {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# ==========================================================================================
# Processing asset: ETHUSDT
# Tuning baseline model...
# [BASE] config 1/18 | cv_mse=0.00665692 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 2/18 | cv_mse=0.00671552 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 3/18 | cv_mse=0.00788587 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 4/18 | cv_mse=0.00638116 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 5/18 | cv_mse=0.00678555 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 6/18 | cv_mse=0.00623931 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 7/18 | cv_mse=0.00628354 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 8/18 | cv_mse=0.00634441 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 9/18 | cv_mse=0.00739734 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 10/18 | cv_mse=0.00619936 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 11/18 | cv_mse=0.00718697 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 12/18 | cv_mse=0.00632799 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 13/18 | cv_mse=0.00642851 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 14/18 | cv_mse=0.00703098 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 15/18 | cv_mse=0.00913684 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 16/18 | cv_mse=0.00777324 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 17/18 | cv_mse=0.00662136 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 18/18 | cv_mse=0.00623260 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best baseline config: {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# Tuning regime-aware model...
# [REG] config 1/18 | cv_mse=0.00667580 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 2/18 | cv_mse=0.00686469 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 3/18 | cv_mse=0.00687366 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 4/18 | cv_mse=0.00634776 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 5/18 | cv_mse=0.00792428 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 6/18 | cv_mse=0.00639459 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 7/18 | cv_mse=0.00623799 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 8/18 | cv_mse=0.00680457 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 9/18 | cv_mse=0.00799026 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 10/18 | cv_mse=0.00649311 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 11/18 | cv_mse=0.00680373 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 12/18 | cv_mse=0.00637070 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 13/18 | cv_mse=0.00671198 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 14/18 | cv_mse=0.00755829 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 15/18 | cv_mse=0.00869888 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 16/18 | cv_mse=0.00721174 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 17/18 | cv_mse=0.00702926 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 18/18 | cv_mse=0.00634283 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best regime config: {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# ==========================================================================================
# Processing asset: LINKUSDT
# Tuning baseline model...
# [BASE] config 1/18 | cv_mse=0.00987988 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 2/18 | cv_mse=0.01002795 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 3/18 | cv_mse=0.00987918 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 4/18 | cv_mse=0.01002302 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 5/18 | cv_mse=0.01028559 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 6/18 | cv_mse=0.01012522 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 7/18 | cv_mse=0.00989419 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 8/18 | cv_mse=0.01031463 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 9/18 | cv_mse=0.00995654 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 10/18 | cv_mse=0.01009332 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 11/18 | cv_mse=0.01031834 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 12/18 | cv_mse=0.00982281 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 13/18 | cv_mse=0.00992662 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 14/18 | cv_mse=0.01004025 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 15/18 | cv_mse=0.01026458 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 16/18 | cv_mse=0.01002253 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 17/18 | cv_mse=0.01008357 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 18/18 | cv_mse=0.00968023 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best baseline config: {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Tuning regime-aware model...
# [REG] config 1/18 | cv_mse=0.01010187 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 2/18 | cv_mse=0.00994554 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 3/18 | cv_mse=0.01019619 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 4/18 | cv_mse=0.00973908 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 5/18 | cv_mse=0.01028082 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 6/18 | cv_mse=0.00996452 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 7/18 | cv_mse=0.00964860 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 8/18 | cv_mse=0.00967992 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 9/18 | cv_mse=0.01010300 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 10/18 | cv_mse=0.00960043 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 11/18 | cv_mse=0.01023998 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 12/18 | cv_mse=0.00975569 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 13/18 | cv_mse=0.00981711 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 14/18 | cv_mse=0.01021371 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 15/18 | cv_mse=0.01044554 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 16/18 | cv_mse=0.01057227 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 17/18 | cv_mse=0.01000301 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 18/18 | cv_mse=0.00997018 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best regime config: {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# ==========================================================================================
# Processing asset: LTCUSDT
# Tuning baseline model...
# [BASE] config 1/18 | cv_mse=0.00795974 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 2/18 | cv_mse=0.00796610 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 3/18 | cv_mse=0.00778163 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# ...
# Best baseline config: {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# Tuning regime-aware model...
# [REG] config 1/18 | cv_mse=0.00850469 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 2/18 | cv_mse=0.00860528 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 3/18 | cv_mse=0.00846236 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 4/18 | cv_mse=0.00803708 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 5/18 | cv_mse=0.00891820 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 6/18 | cv_mse=0.00801655 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 7/18 | cv_mse=0.00801618 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 8/18 | cv_mse=0.00815364 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 9/18 | cv_mse=0.00821535 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 10/18 | cv_mse=0.00802489 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 11/18 | cv_mse=0.00850435 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 12/18 | cv_mse=0.00781871 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 13/18 | cv_mse=0.00806906 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 14/18 | cv_mse=0.00885500 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 15/18 | cv_mse=0.00832690 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 16/18 | cv_mse=0.00847910 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 17/18 | cv_mse=0.00819735 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 18/18 | cv_mse=0.00801746 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best regime config: {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# ==========================================================================================
# Processing asset: XRPUSDT
# Tuning baseline model...
# [BASE] config 1/18 | cv_mse=0.01021528 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 2/18 | cv_mse=0.01044440 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 3/18 | cv_mse=0.01028611 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 4/18 | cv_mse=0.01011356 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 5/18 | cv_mse=0.01065432 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 6/18 | cv_mse=0.01006765 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 7/18 | cv_mse=0.00991193 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 8/18 | cv_mse=0.00991424 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 9/18 | cv_mse=0.01099657 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 10/18 | cv_mse=0.00990440 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 11/18 | cv_mse=0.01097243 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 12/18 | cv_mse=0.00984766 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 13/18 | cv_mse=0.01029042 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [BASE] config 14/18 | cv_mse=0.01087299 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [BASE] config 15/18 | cv_mse=0.01034867 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 16/18 | cv_mse=0.01093442 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 17/18 | cv_mse=0.00992799 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [BASE] config 18/18 | cv_mse=0.00983884 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best baseline config: {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Tuning regime-aware model...
# [REG] config 1/18 | cv_mse=0.01038807 | {'seq_len': 15, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 2/18 | cv_mse=0.01032560 | {'seq_len': 10, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 3/18 | cv_mse=0.01029687 | {'seq_len': 20, 'learning_rate': 0.0001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.2, 'batch_size': 32, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 4/18 | cv_mse=0.00990002 | {'seq_len': 20, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.2, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 5/18 | cv_mse=0.01104006 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 64, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 6/18 | cv_mse=0.01015674 | {'seq_len': 15, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 7/18 | cv_mse=0.00999197 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 8/18 | cv_mse=0.01022024 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 9/18 | cv_mse=0.01134035 | {'seq_len': 30, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 10/18 | cv_mse=0.01008674 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 11/18 | cv_mse=0.00982951 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 12/18 | cv_mse=0.00982569 | {'seq_len': 10, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 32, 'epochs': 35, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 13/18 | cv_mse=0.01047195 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 32, 'num_layers': 2, 'dropout': 0.3, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0, 'patience': 5}
# [REG] config 14/18 | cv_mse=0.01093142 | {'seq_len': 20, 'learning_rate': 0.001, 'hidden_size': 128, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 35, 'weight_decay': 1e-05, 'patience': 5}
# [REG] config 15/18 | cv_mse=0.01143991 | {'seq_len': 30, 'learning_rate': 5e-05, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.3, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 16/18 | cv_mse=0.01069012 | {'seq_len': 10, 'learning_rate': 0.0005, 'hidden_size': 32, 'num_layers': 1, 'dropout': 0.0, 'batch_size': 32, 'epochs': 20, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 17/18 | cv_mse=0.00976918 | {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# [REG] config 18/18 | cv_mse=0.00980221 | {'seq_len': 25, 'learning_rate': 5e-05, 'hidden_size': 128, 'num_layers': 2, 'dropout': 0.1, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0, 'patience': 5}
# Best regime config: {'seq_len': 15, 'learning_rate': 5e-05, 'hidden_size': 64, 'num_layers': 2, 'dropout': 0.0, 'batch_size': 64, 'epochs': 50, 'weight_decay': 0.0001, 'patience': 5}
# Saved summary metrics to: outputs\lstm_model_output\summary_metrics.csv
# Saved all forecasts to:  outputs\lstm_model_output\all_forecasts.csv
#        asset model_type   val_mse   val_mae    val_da  test_mse  test_mae  \
# 0    ADAUSDT   baseline  0.017746  0.095995  0.498607  0.015018  0.095115
# 1    ADAUSDT     regime  0.023651  0.103859  0.545961  0.019689  0.108187
# 2    BCHUSDT   baseline  0.017894  0.097667  0.529248  0.007070  0.065057
# 3    BCHUSDT     regime  0.023362  0.112378  0.504178  0.009761  0.078634
# 4    BNBUSDT   baseline  0.016246  0.109091  0.509749  0.009393  0.063571
# 5    BNBUSDT     regime  0.015628  0.096858  0.428969  0.008402  0.066453
# 6    BTCUSDT   baseline  0.009712  0.079234  0.442897  0.002929  0.041383
# 7    BTCUSDT     regime  0.030027  0.139511  0.459610  0.003443  0.046963
# 8    ETHUSDT   baseline  0.018570  0.105020  0.498607  0.012550  0.079806
# 9    ETHUSDT     regime  0.008466  0.072125  0.576602  0.009755  0.074683
# 10  LINKUSDT   baseline  0.014595  0.095111  0.557103  0.013001  0.089501
# 11  LINKUSDT     regime  0.018365  0.108041  0.537604  0.016040  0.099397
# 12   LTCUSDT   baseline  0.015125  0.089097  0.532033  0.022324  0.112064
# 13   LTCUSDT     regime  0.009017  0.067969  0.590529  0.010851  0.079141
# 14   XRPUSDT   baseline  0.023986  0.101744  0.526462  0.040410  0.177661
# 15   XRPUSDT     regime  0.022097  0.098033  0.493036  0.024843  0.126496
#
#      test_da  hp_seq_len  hp_learning_rate  hp_hidden_size  hp_num_layers  \
# 0   0.589385          20           0.00010              64              1
# 1   0.511173          30           0.00100              32              1
# 2   0.606145          15           0.00050              32              2
# 3   0.508380          10           0.00050              32              2
# 4   0.594972          10           0.00005             128              2
# 5   0.539106          20           0.00050              32              2
# 6   0.466480          10           0.00005             128              2
# 7   0.469274          15           0.00050              32              2
# 8   0.603352          10           0.00050              32              2
# 9   0.555866          10           0.00005             128              2
# 10  0.536313          25           0.00005             128              2
# 11  0.578212          10           0.00050              32              2
# 12  0.494413          20           0.00050              32              2
# 13  0.472067          10           0.00005              64              2
# 14  0.553073          25           0.00005             128              2
# 15  0.553073          15           0.00005              64              2
#
#     hp_dropout  hp_batch_size  hp_epochs  hp_weight_decay  hp_patience
# 0          0.2             32         50          0.00000            5
# 1          0.0             32         20          0.00000            5
# 2          0.3             32         20          0.00000            5
# 3          0.0             64         50          0.00001            5
# 4          0.1             32         35          0.00010            5
# 5          0.2             64         50          0.00001            5
# 6          0.1             32         35          0.00010            5
# 7          0.3             32         20          0.00000            5
# 8          0.0             64         50          0.00001            5
# 9          0.1             32         35          0.00010            5
# 10         0.1             64         50          0.00000            5
# 11         0.0             64         50          0.00001            5
# 12         0.2             64         50          0.00001            5
# 13         0.1             32         35          0.00010            5
# 14         0.1             64         50          0.00000            5
# 15         0.0             64         50          0.00010            5

# %% [markdown]
# ## Quick result views
#
# The first table shows all saved summary metrics. The second table focuses on the test MSE difference between the regime-aware and baseline models.

# %%
summary_df = pd.read_csv(OUTPUT_DIR / "summary_metrics.csv")
display(summary_df.sort_values(["asset", "model_type"]).reset_index(drop=True))

pivot_test_mse = summary_df.pivot(index="asset", columns="model_type", values="test_mse")
pivot_test_mse["regime_minus_baseline"] = pivot_test_mse["regime"] - pivot_test_mse["baseline"]
display(pivot_test_mse.sort_index())
# Out:
#        asset model_type   val_mse   val_mae    val_da  test_mse  test_mae  \
# 0    ADAUSDT   baseline  0.017746  0.095995  0.498607  0.015018  0.095115
# 1    ADAUSDT     regime  0.023651  0.103859  0.545961  0.019689  0.108187
# 2    BCHUSDT   baseline  0.017894  0.097667  0.529248  0.007070  0.065057
# 3    BCHUSDT     regime  0.023362  0.112378  0.504178  0.009761  0.078634
# 4    BNBUSDT   baseline  0.016246  0.109091  0.509749  0.009393  0.063571
# 5    BNBUSDT     regime  0.015628  0.096858  0.428969  0.008402  0.066453
# 6    BTCUSDT   baseline  0.009712  0.079234  0.442897  0.002929  0.041383
# 7    BTCUSDT     regime  0.030027  0.139511  0.459610  0.003443  0.046963
# 8    ETHUSDT   baseline  0.018570  0.105020  0.498607  0.012550  0.079806
# 9    ETHUSDT     regime  0.008466  0.072125  0.576602  0.009755  0.074683
# 10  LINKUSDT   baseline  0.014595  0.095111  0.557103  0.013001  0.089501
# 11  LINKUSDT     regime  0.018365  0.108041  0.537604  0.016040  0.099397
# 12   LTCUSDT   baseline  0.015125  0.089097  0.532033  0.022324  0.112064
# 13   LTCUSDT     regime  0.009017  0.067969  0.590529  0.010851  0.079141
# 14   XRPUSDT   baseline  0.023986  0.101744  0.526462  0.040410  0.177661
# 15   XRPUSDT     regime  0.022097  0.098033  0.493036  0.024843  0.126496
#
#      test_da  hp_seq_len  hp_learning_rate  hp_hidden_size  hp_num_layers  \
# 0   0.589385          20           0.00010              64              1
# 1   0.511173          30           0.00100              32              1
# 2   0.606145          15           0.00050              32              2
# 3   0.508380          10           0.00050              32              2
# 4   0.594972          10           0.00005             128              2
# 5   0.539106          20           0.00050              32              2
# 6   0.466480          10           0.00005             128              2
# 7   0.469274          15           0.00050              32              2
# 8   0.603352          10           0.00050              32              2
# 9   0.555866          10           0.00005             128              2
# 10  0.536313          25           0.00005             128              2
# 11  0.578212          10           0.00050              32              2
# 12  0.494413          20           0.00050              32              2
# 13  0.472067          10           0.00005              64              2
# 14  0.553073          25           0.00005             128              2
# 15  0.553073          15           0.00005              64              2
#
#     hp_dropout  hp_batch_size  hp_epochs  hp_weight_decay  hp_patience
# 0          0.2             32         50          0.00000            5
# 1          0.0             32         20          0.00000            5
# 2          0.3             32         20          0.00000            5
# 3          0.0             64         50          0.00001            5
# 4          0.1             32         35          0.00010            5
# 5          0.2             64         50          0.00001            5
# 6          0.1             32         35          0.00010            5
# 7          0.3             32         20          0.00000            5
# 8          0.0             64         50          0.00001            5
# 9          0.1             32         35          0.00010            5
# 10         0.1             64         50          0.00000            5
# 11         0.0             64         50          0.00001            5
# 12         0.2             64         50          0.00001            5
# 13         0.1             32         35          0.00010            5
# 14         0.1             64         50          0.00000            5
# 15         0.0             64         50          0.00010            5
# model_type  baseline    regime  regime_minus_baseline
# asset
# ADAUSDT     0.015018  0.019689               0.004671
# BCHUSDT     0.007070  0.009761               0.002692
# BNBUSDT     0.009393  0.008402              -0.000990
# BTCUSDT     0.002929  0.003443               0.000514
# ETHUSDT     0.012550  0.009755              -0.002795
# LINKUSDT    0.013001  0.016040               0.003039
# LTCUSDT     0.022324  0.010851              -0.011473
# XRPUSDT     0.040410  0.024843              -0.015566

# %% [markdown]
# Spearman rank correlation

# %%
from scipy.stats import spearmanr

forecasts_df = pd.read_csv(OUTPUT_DIR / "all_forecasts.csv", parse_dates=["date"])
test_forecasts = forecasts_df[forecasts_df["split"] == "test"]

# Compute Spearman rank IC at each date
rank_ic_rows = []
for model_type, mgrp in test_forecasts.groupby("model_type"):
    for date, dgrp in mgrp.groupby("date"):
        if len(dgrp) < 3:
            continue
        corr, _ = spearmanr(dgrp["y_true"], dgrp["y_pred"])
        rank_ic_rows.append({"model_type": model_type, "date": date, "rank_ic": corr})

rank_ic_df = pd.DataFrame(rank_ic_rows)

# Filter to weekly rebalancing dates only
dates_sorted = sorted(test_forecasts["date"].unique())
weekly_dates = [dates_sorted[i] for i in range(0, len(dates_sorted), 7)]
rank_ic_weekly = rank_ic_df[rank_ic_df["date"].isin(weekly_dates)]

# Summary
print("Rank IC at weekly rebalancing dates:")
display(rank_ic_weekly.groupby("model_type")["rank_ic"].agg(["mean","median","std","count"]).round(4))

print("\nFraction of rebalancing dates with positive rank IC:")
display(rank_ic_weekly.groupby("model_type")["rank_ic"].apply(lambda x: (x > 0).mean()).round(4))

rank_ic_df.to_csv(OUTPUT_DIR / "rank_ic.csv", index=False)
# Out:
# Rank IC at weekly rebalancing dates:
#               mean  median     std  count
# model_type
# baseline    0.0408  0.0000  0.3627     52
# regime      0.0481  0.1071  0.4375     52
# Fraction of rebalancing dates with positive rank IC:
# model_type
# baseline    0.5000
# regime      0.5385
# Name: rank_ic, dtype: float64

# %% [markdown]
# ## Inspect one asset's tuning results and forecasts
#
# Replace `ASSET_TO_INSPECT` with any asset code if you want a closer look at that asset's hyperparameter search and forecast file.

# %%
ASSET_TO_INSPECT = assets[0]
asset_dir = OUTPUT_DIR / ASSET_TO_INSPECT

print("Inspecting asset:", ASSET_TO_INSPECT)
display(pd.read_csv(asset_dir / "baseline_tuning_results.csv").head())
display(pd.read_csv(asset_dir / "regime_tuning_results.csv").head())
display(pd.read_csv(asset_dir / "forecasts.csv").head())
# Out:
# Inspecting asset: ADAUSDT
#    config_id    cv_mse  seq_len  learning_rate  hidden_size  num_layers  \
# 0          3  0.008623       20        0.00010           64           1
# 1         17  0.008690       15        0.00005           64           2
# 2          1  0.008725       15        0.00100           32           2
# 3          8  0.008749       10        0.00005           32           2
# 4          6  0.008768       15        0.00050           32           2
#
#    dropout  batch_size  epochs  weight_decay  patience
# 0      0.2          32      50        0.0000         5
# 1      0.0          64      50        0.0001         5
# 2      0.1          32      50        0.0000         5
# 3      0.3          32      20        0.0001         5
# 4      0.3          32      20        0.0000         5
#    config_id    cv_mse  seq_len  learning_rate  hidden_size  num_layers  \
# 0          9  0.008644       30        0.00100           32           1
# 1         18  0.008738       25        0.00005          128           2
# 2         17  0.008782       15        0.00005           64           2
# 3          7  0.008833       10        0.00005          128           2
# 4         10  0.008858       10        0.00050           32           2
#
#    dropout  batch_size  epochs  weight_decay  patience
# 0      0.0          32      20       0.00000         5
# 1      0.1          64      50       0.00000         5
# 2      0.0          64      50       0.00010         5
# 3      0.1          32      35       0.00010         5
# 4      0.0          64      50       0.00001         5
#     crypto        date split model_type    y_true    y_pred
# 0  ADAUSDT  2024-01-01   val   baseline -0.141079 -0.056226
# 1  ADAUSDT  2024-01-02   val   baseline -0.166123 -0.050170
# 2  ADAUSDT  2024-01-03   val   baseline  0.016208 -0.036848
# 3  ADAUSDT  2024-01-04   val   baseline  0.021010 -0.052894
# 4  ADAUSDT  2024-01-05   val   baseline  0.011387 -0.042031

# %% [markdown]
# ## Plotting
#
# This plot compares the predicted and actual 7-day returns for one chosen asset on the test split. It is just a quick visual sanity check, not a full evaluation.

# %% [markdown]
# ### Regime

# %%
for asset in assets: 
    ASSET_TO_PLOT = asset
    PLOT_MODEL = "regime"  

    plot_df = pd.read_csv(OUTPUT_DIR / ASSET_TO_PLOT / "forecasts.csv", parse_dates=["date"])
    plot_df = plot_df[(plot_df["split"] == "test") & (plot_df["model_type"] == PLOT_MODEL)].copy()

    plt.figure(figsize=(10, 4))
    plt.plot(plot_df["date"], plot_df["y_true"], label="Actual")
    plt.plot(plot_df["date"], plot_df["y_pred"], label="Predicted")
    plt.title(f"{ASSET_TO_PLOT} | {PLOT_MODEL} | Test 7-day return forecasts")
    plt.xlabel("Prediction date (t), predicting t → t+7 return")
    plt.ylabel("7-day cumulative return")
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Baseline

# %%
for asset in assets: 
    ASSET_TO_PLOT = asset
    PLOT_MODEL = "baseline"  

    plot_df = pd.read_csv(OUTPUT_DIR / ASSET_TO_PLOT / "forecasts.csv", parse_dates=["date"])
    plot_df = plot_df[(plot_df["split"] == "test") & (plot_df["model_type"] == PLOT_MODEL)].copy()

    plt.figure(figsize=(10, 4))
    plt.plot(plot_df["date"], plot_df["y_true"], label="Actual")
    plt.plot(plot_df["date"], plot_df["y_pred"], label="Predicted")
    plt.title(f"{ASSET_TO_PLOT} | {PLOT_MODEL} | Test 7-day return forecasts")
    plt.xlabel("Prediction date (t), predicting t → t+7 return")
    plt.ylabel("7-day cumulative return")
    plt.legend()
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# %%
# Plot train and validation loss for best model configurations (baseline and regime) for a chosen asset
ASSET_TO_PLOT_LOSS = assets[0]  # Change as needed
asset_dir = OUTPUT_DIR / ASSET_TO_PLOT_LOSS

# Baseline
baseline_val_history = pd.read_csv(asset_dir / "baseline_val_fit_history.csv")
baseline_tuning = pd.read_csv(asset_dir / "baseline_tuning_results.csv")

# Regime-aware
regime_val_history = pd.read_csv(asset_dir / "regime_val_fit_history.csv")
regime_tuning = pd.read_csv(asset_dir / "regime_tuning_results.csv")

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(baseline_val_history["epoch"], baseline_val_history["train_loss"], label="Train Loss")
# If validation loss is available, plot it (not always present if val_loader=None)
if "val_loss" in baseline_val_history.columns:
    plt.plot(baseline_val_history["epoch"], baseline_val_history["val_loss"], label="Val Loss")
plt.title(f"Baseline Model: {ASSET_TO_PLOT_LOSS}")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(regime_val_history["epoch"], regime_val_history["train_loss"], label="Train Loss")
if "val_loss" in regime_val_history.columns:
    plt.plot(regime_val_history["epoch"], regime_val_history["val_loss"], label="Val Loss")
plt.title(f"Regime-aware Model: {ASSET_TO_PLOT_LOSS}")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()

plt.tight_layout()
plt.show()
